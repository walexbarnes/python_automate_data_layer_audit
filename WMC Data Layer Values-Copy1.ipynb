# %%
#pip install selenium

# %%
import pandas as pd
from selenium import webdriver

# %%
driver = webdriver.Chrome()
my_urls = ["https://uat2-aemcs.REDACTED.com/products","https://uat2-aemcs.REDACTED.com/products/door-styles.html","https://uat2-aemcs.REDACTED.com/products/door-styles/macarthur","https://uat2-aemcs.REDACTED.com/products/door-styles/san-mateo","https://uat2-aemcs.REDACTED.com/products/door-styles/portola","https://uat2-aemcs.REDACTED.com/products/door-styles/westerly","https://uat2-aemcs.REDACTED.com/products/door-styles/adelaide","https://uat2-aemcs.REDACTED.com/products/door-styles/garner","https://uat2-aemcs.REDACTED.com/products/door-styles/leesburg","https://uat2-aemcs.REDACTED.com/products/door-styles/glen-ellen","https://uat2-aemcs.REDACTED.com/products/door-styles/brookland","https://uat2-aemcs.REDACTED.com/products/door-styles/savannah","https://uat2-aemcs.REDACTED.com/products/door-styles/shorebrook","https://uat2-aemcs.REDACTED.com/products/door-styles/hanover","https://uat2-aemcs.REDACTED.com/products/door-styles/reading","https://uat2-aemcs.REDACTED.com/products/materials-colors","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-sage","https://uat2-aemcs.REDACTED.com/products/materials-colors/cherry-amber","https://uat2-aemcs.REDACTED.com/products/materials-colors/cherry-java","https://uat2-aemcs.REDACTED.com/products/materials-colors/duarform-linen","https://uat2-aemcs.REDACTED.com/products/materials-colors/duraform-harbor","https://uat2-aemcs.REDACTED.com/products/materials-colors/duraform-stone","https://uat2-aemcs.REDACTED.com/products/materials-colors/duraform-drift","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-black","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-navy","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-mist","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-linen","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-boulder","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-ember-glaze","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-harbor","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-biscotti-glaze","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-pewter-glaze","https://uat2-aemcs.REDACTED.com/products/materials-colors/painted-vanilla","https://uat2-aemcs.REDACTED.com/products/materials-colors/maple-slate","https://uat2-aemcs.REDACTED.com/products/materials-colors/maple-truffle","https://uat2-aemcs.REDACTED.com/products/materials-colors/maple-cognac","https://uat2-aemcs.REDACTED.com/products/materials-colors/maple-spice","https://uat2-aemcs.REDACTED.com/products/materials-colors/maple-rye","https://uat2-aemcs.REDACTED.com/products/materials-colors/duraform-espresso","https://uat2-aemcs.REDACTED.com/products/materials-colors/duraform-breeze","https://uat2-aemcs.REDACTED.com/products/organization-accents","https://uat2-aemcs.REDACTED.com/products/organization-accents/knobs-pulls-handles","https://uat2-aemcs.REDACTED.com/products/organization-accents/organization","https://uat2-aemcs.REDACTED.com/products/organization-accents/decorative-accessories","https://uat2-aemcs.REDACTED.com/products/organization-accents/range-hoods","https://uat2-aemcs.REDACTED.com/products/how-its-made","https://uat2-aemcs.REDACTED.com/products/catalog","https://uat2-aemcs.REDACTED.com/products/resources","https://uat2-aemcs.REDACTED.com/products/order-samples"]
site_sections = []
sub_sections = []
sub_section_2s = []
page_names = []

for page in my_urls: 
    driver.get(page)
    site_section = driver.execute_script('var myDl = adobeDataLayer.getState(); var myDlKeys = Object.keys(myDl.page); var mySection = myDl.page[myDlKeys[0]]["section"]; return mySection')
    site_sections.append(site_section)
    sub_section = driver.execute_script('var myDl = adobeDataLayer.getState(); var myDlKeys = Object.keys(myDl.page); var mySubSection = myDl.page[myDlKeys[0]]["subSection"]; return mySubSection;')
    sub_sections.append(sub_section)
    sub_section_2= driver.execute_script('var myDl = adobeDataLayer.getState(); var myDlKeys = Object.keys(myDl.page); var mySubSection2 = myDl.page[myDlKeys[0]]["subSection2"]; return mySubSection2;')
    sub_section_2s.append(sub_section_2)
    page_name = driver.execute_script('var myDl = adobeDataLayer.getState(); var myDlKeys = Object.keys(myDl.page); var myPage = myDl.page[myDlKeys[0]]["name"]; return myPage;')
    page_names.append(page_name)
    
dict = {"page_url":my_urls,
       "site_section":site_sections,
       "sub_section":sub_sections,
       "sub_section_2":sub_section_2s,
       "page_name":page_names}

df = pd.DataFrame(dict)

display(df)
# Out:
#                                              page_url site_section  \
# 0   https://uat2-aemcs.woodmarkcabinetry.com/products     products
# 1   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 2   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 3   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 4   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 5   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 6   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 7   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 8   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 9   https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 10  https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 11  https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# 12  https://uat2-aemcs.woodmarkcabinetry.com/produ...     products
# ...

# %%
df.to_csv("scanresults.csv")

# %%
driver.quit()

# %%
driver = webdriver.Chrome()
my_urls =["https://uat2-aemcs.woodmarkcabinetry.com/products","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles.html","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles.html","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/macarthur","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/san-mateo","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/portola","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/westerly","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/adelaide","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/garner","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/leesburg","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/glen-ellen","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/brookland","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/savannah","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/shorebrook","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/hanover","https://uat2-aemcs.woodmarkcabinetry.com/products/door-styles/reading","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-sage","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/cherry-amber","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/cherry-java","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duarform-linen","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duraform-harbor","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duraform-stone","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duraform-drift","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-black","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-navy","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-mist","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-linen","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-boulder","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-ember-glaze","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-harbor","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-biscotti-glaze","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-pewter-glaze","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/painted-vanilla","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/maple-slate","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/maple-truffle","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/maple-cognac","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/maple-spice","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/maple-rye","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duraform-espresso","https://uat2-aemcs.woodmarkcabinetry.com/products/materials-colors/duraform-breeze","https://uat2-aemcs.woodmarkcabinetry.com/products/organization-accents","https://uat2-aemcs.woodmarkcabinetry.com/products/organization-accents/knobs-pulls-handles","https://uat2-aemcs.woodmarkcabinetry.com/products/organization-accents/organization","https://uat2-aemcs.woodmarkcabinetry.com/products/organization-accents/decorative-accessories","https://uat2-aemcs.woodmarkcabinetry.com/products/organization-accents/range-hoods","https://uat2-aemcs.woodmarkcabinetry.com/products/how-its-made","https://uat2-aemcs.woodmarkcabinetry.com/products/catalog","https://uat2-aemcs.woodmarkcabinetry.com/products/resources","https://uat2-aemcs.woodmarkcabinetry.com/products/order-samples","https://uat2-aemcs.woodmarkcabinetry.com/inspiration","https://uat2-aemcs.woodmarkcabinetry.com/inspiration/gallery#all-rooms","https://uat2-aemcs.woodmarkcabinetry.com/inspiration/trends","https://uat2-aemcs.woodmarkcabinetry.complanner.wmc.com","https://uat2-aemcs.woodmarkcabinetry.com/inspiration/articles","https://uat2-aemcs.woodmarkcabinetry.com/inspiration/style-quiz","https://uat2-aemcs.woodmarkcabinetry.com/planning","https://uat2-aemcs.woodmarkcabinetry.com/planning/work-with-us","https://uat2-aemcs.woodmarkcabinetry.com/planning/how-to-measure-your-space","https://uat2-aemcs.woodmarkcabinetry.com/planning/budget-estimator","https://uat2-aemcs.woodmarkcabinetry.com/planning/project-timeline","https://uat2-aemcs.woodmarkcabinetry.com/planning/articles","https://uat2-aemcs.woodmarkcabinetry.com/pros","https://uat2-aemcs.woodmarkcabinetry.com/pros/products","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles?finish=","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles?design-style=","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles?material=","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles?price=","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles/compare","https://uat2-aemcs.woodmarkcabinetry.com/pros/products/door-styles/configure.html?style=[value]&material=[value]&color=[value]","https://uat2-aemcs.woodmarkcabinetry.com/pros/benefits","https://uat2-aemcs.woodmarkcabinetry.com/pros/construction-and-options","https://uat2-aemcs.woodmarkcabinetry.compros/guides#catalog-and-brochures","https://uat2-aemcs.woodmarkcabinetry.compros/guides#specification-guides","https://uat2-aemcs.woodmarkcabinetry.compros/guides#installation-instructions","https://uat2-aemcs.woodmarkcabinetry.compros/guides#planning-tools","https://uat2-aemcs.woodmarkcabinetry.compros/success-stories","https://uat2-aemcs.woodmarkcabinetry.com/about/why-woodmark","https://uat2-aemcs.woodmarkcabinetry.com/about/faqs","https://uat2-aemcs.woodmarkcabinetry.com/about/reviews","https://uat2-aemcs.woodmarkcabinetry.com/about/contact","https://uat2-aemcs.woodmarkcabinetry.com/about/cabinet-care","https://uat2-aemcs.woodmarkcabinetry.com/about/warranty","https://uat2-aemcs.woodmarkcabinetry.com/about/sample-door-rebate","https://uat2-aemcs.woodmarkcabinetry.com/my-project","https://uat2-aemcs.woodmarkcabinetry.com/search","https://uat2-aemcs.woodmarkcabinetry.com/404","https://uat2-aemcs.woodmarkcabinetry.com/500","https://uat2-aemcs.woodmarkcabinetry.com/503","https://uat2-aemcs.woodmarkcabinetry.com/schedule"]
site_sections = []
sub_sections = []
sub_section_2s = []
page_names = []
is_fallbacks = []

for page in my_urls: 
    try:
        driver.get(page)
        site_section = driver.execute_script('function getSiteSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr[1].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 3 ? "overview" : splitArr[2].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection2(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 4 ? "overview" : splitArr[3].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getPageName(arg){if (isErrorPage(document.title)){return "wlc | 404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "wmc | home" : getSubSection(arg) == "overview" ? "wmc | "+getSiteSection(arg)+" : overview" : "wmc | "+getSiteSection(arg)+ " : "+getSubSection(arg)+" : "+getSubSection2(arg);return myReturnVal.replace(".html","");}function isErrorPage(arg){return arg.toLowerCase().indexOf("not found")>-1 ? true : false;};var myKey = "section";var myDl = adobeDataLayer.getState();var myDlKeys = Object.keys(myDl.page);return (typeof myDl.page[myDlKeys[0]][myKey] == "string") ? myDl.page[myDlKeys[0]][myKey] : getSiteSection(location.hostname+location.pathname);')
        site_sections.append(site_section)
        sub_section = driver.execute_script('function getSiteSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr[1].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 3 ? "overview" : splitArr[2].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection2(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 4 ? "overview" : splitArr[3].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getPageName(arg){if (isErrorPage(document.title)){return "wlc | 404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "wmc | home" : getSubSection(arg) == "overview" ? "wmc | "+getSiteSection(arg)+" : overview" : "wmc | "+getSiteSection(arg)+ " : "+getSubSection(arg)+" : "+getSubSection2(arg);return myReturnVal.replace(".html","");}function isErrorPage(arg){return arg.toLowerCase().indexOf("not found")>-1 ? true : false;};var myKey = "subSection";var myDl = adobeDataLayer.getState();var myDlKeys = Object.keys(myDl.page);return typeof myDl.page[myDlKeys[0]][myKey] == "string" ? myDl.page[myDlKeys[0]][myKey] : getSubSection(location.hostname+location.pathname);')
        sub_sections.append(sub_section)
        sub_section_2= driver.execute_script('function getSiteSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr[1].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 3 ? "overview" : splitArr[2].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection2(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 4 ? "overview" : splitArr[3].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getPageName(arg){if (isErrorPage(document.title)){return "wlc | 404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "wmc | home" : getSubSection(arg) == "overview" ? "wmc | "+getSiteSection(arg)+" : overview" : "wmc | "+getSiteSection(arg)+ " : "+getSubSection(arg)+" : "+getSubSection2(arg);return myReturnVal.replace(".html","");}function isErrorPage(arg){return arg.toLowerCase().indexOf("not found")>-1 ? true : false;}var myDl = adobeDataLayer.getState();var myDlKeys = Object.keys(myDl.page);return typeof myDl.page[myDlKeys[0]]["subSection2"] == "string" ? myDl.page[myDlKeys[0]]["subSection2"] : getSubSection2(location.hostname+location.pathname);')
        sub_section_2s.append(sub_section_2)
        fallback_status = driver.execute_script('var myDl = adobeDataLayer.getState();var myDlKeys = Object.keys(myDl.page);var myPage = myDl.page[myDlKeys[0]]["name"];return (typeof myPage == "string" && myPage.indexOf("wmc")>-1) ? "false" : "true";')
        is_fallbacks.append(fallback_status)
        page_name = driver.execute_script('function getSiteSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr[1].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 3 ? "overview" : splitArr[2].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getSubSection2(arg){if (isErrorPage(document.title)){return "404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "home" : splitArr.length < 4 ? "overview" : splitArr[3].toLowerCase().replaceAll("-"," ");return myReturnVal.replace(".html","");}function getPageName(arg){if (isErrorPage(document.title)){return "wlc | 404";};var splitArr = arg.split("/");var myReturnVal = splitArr[1] == "" ? "wmc | home" : getSubSection(arg) == "overview" ? "wmc | "+getSiteSection(arg)+" : overview" : "wmc | "+getSiteSection(arg)+ " : "+getSubSection(arg)+" : "+getSubSection2(arg);return myReturnVal.replace(".html","");}function isErrorPage(arg){return arg.toLowerCase().indexOf("not found")>-1 ? true : false;};var myDl = adobeDataLayer.getState();var myDlKeys = Object.keys(myDl.page);var myPage = myDl.page[myDlKeys[0]]["name"];return (typeof myPage == "string" && myPage.indexOf("wmc")>-1) ? myPage : getPageName(location.hostname+location.pathname);')
        page_names.append(page_name)
    except:
        site_sections.append("error")
        sub_sections.append("error")
        sub_section_2s.append("error")
        is_fallbacks.append("error")     
        page_names.append("error")
        
dict = {"page_url":my_urls,
       "site_sections":site_sections,
       "sub_section":sub_sections,
       "sub_section_2":sub_section_2s,
        "is_fallback":is_fallbacks,
       "page_name":page_names}

df = pd.DataFrame(dict)

display(df)
# Out:
#                                              page_url site_sections  \
# 0   https://uat2-aemcs.woodmarkcabinetry.com/products      products
# 1   https://uat2-aemcs.woodmarkcabinetry.com/produ...      products
# 2   https://uat2-aemcs.woodmarkcabinetry.com/produ...      products
# 3   https://uat2-aemcs.woodmarkcabinetry.com/produ...      products
# 4   https://uat2-aemcs.woodmarkcabinetry.com/produ...      products
# ..                                                ...           ...
# 86    https://uat2-aemcs.woodmarkcabinetry.com/search        search
# 87       https://uat2-aemcs.woodmarkcabinetry.com/404           404
# 88       https://uat2-aemcs.woodmarkcabinetry.com/500           500
# 89       https://uat2-aemcs.woodmarkcabinetry.com/503           503
# 90  https://uat2-aemcs.woodmarkcabinetry.com/schedule      schedule
#
#      sub_section sub_section_2 is_fallback  \
# 0       overview      overview       false
# 1    door styles      overview       false
# ...
